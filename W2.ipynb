# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("Car_sales.csv")
num_attributes = df.shape[1]
print("Number of attributes:", num_attributes)
print(df.shape)
# Out:
# Number of attributes: 15
# (157, 15)

# %% [markdown]
# ## 1.Read top five values

# %%
df=pd.read_csv("Car_sales.csv")
print(df.head())
# Out:
#     Manufacturer              Model  Sales in thousands  4-year resale value  \
# 0  Acura          Integra                        16.919               16.360
# 1  Acura          TL                             39.384               19.875
# 2  Acura          CL                             14.114               18.225
# 3  Acura          RL                              8.588               29.725
# 4  Audi           A4                             20.397               22.255
#
#   Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# 0   172.4        2.639           13.2             28.0      2-Feb-14
# 1   192.9        3.517           17.2             25.0      6-Mar-15
# 2   192.0        3.470           17.2             26.0      1-Apr-14
# 3   196.6        3.850           18.0             22.0      3-Oct-15
# 4   178.0        2.998           16.4             27.0     10-Aug-15

# %% [markdown]
# ## 2. Print dataframe info_data types of each column

# %%
import pandas as pd
df = pd.read_csv("Car_sales.csv")
print("DataFrame Info:")
print(df.info())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  121 non-null    float64
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   155 non-null    float64
#  6   Engine size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb weight          155 non-null    float64
#  12  Fuel capacity        156 non-null    float64
#  13  Fuel efficiency      154 non-null    float64
#  14  Latest Launch        157 non-null    object
# dtypes: float64(11), object(4)
# memory usage: 18.5+ KB
# None

# %% [markdown]
# ## 3. Print number of rows and columns

# %%
import pandas as pd
df = pd.read_csv("Car_sales.csv")
num_rows, num_columns = df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 157
# Number of columns: 15

# %% [markdown]
#   ## 4. Drop duplicate rows_if any
#   ## 5. Print number of rows and columns after dropping duplicates

# %%
# Count duplicate rows
num_duplicates = df.duplicated().sum()

# Print the number of duplicate rows
print(f"Number of duplicate rows: {num_duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
df_cleaned = df.drop_duplicates()
print("Number of rows after removing duplicates:", df_cleaned.shape[0])
print("Number of columns after removing duplicates:",df_cleaned.shape[1])
# Out:
# Number of rows after removing duplicates: 157
# Number of columns after removing duplicates: 15

# %% [markdown]
# ## 6. Print summary statistics for numerical variables

# %%
print("Summary Statistics for Numerical Variables:")
print(df.describe())
# Out:
# Summary Statistics for Numerical Variables:
#        Sales in thousands  4-year resale value  Price in thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# 25%       2.300000  149.500000  103.000000   68.400000  177.575000
# 50%       3.000000  177.500000  107.000000   70.550000  187.900000
# 75%       3.575000  215.000000  112.200000   73.425000  196.125000
# max       8.000000  450.000000  138.700000   79.900000  224.500000
#
#        Curb weight  Fuel capacity  Fuel efficiency
# count   155.000000     156.000000       154.000000
# mean      3.378026      17.951923        23.844156
# std       0.630502       3.887921         4.282706
# min       1.895000      10.300000        15.000000
# 25%       2.971000      15.800000        21.000000
# 50%       3.342000      17.200000        24.000000
# 75%       3.799500      19.575000        26.000000
# max       5.572000      32.000000        45.000000

# %% [markdown]
# ## 7. Print number of missing values in each column

# %%
print("Number of missing values in each column:")
print(df.isnull().sum())
# Out:
# Number of missing values in each column:
# Manufacturer            0
# Model                   0
# Sales in thousands      0
# 4-year resale value    36
# Vehicle type            0
# Price in thousands      2
# Engine size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb weight             2
# Fuel capacity           1
# Fuel efficiency         3
# Latest Launch           0
# dtype: int64

# %% [markdown]
# ## 8. Drop the column with most missing values

# %%
df=df.drop(columns=df.isnull().sum().idxmax())
print(df.shape)
# Out:
# (157, 14)

# %% [markdown]
# ## 9. Drop the rows with categorical missing values

# %%
df = df.dropna(subset=df.select_dtypes(include=['object']).columns)
print(df.shape)
# Out:
# (157, 14)

# %% [markdown]
# ## 10. Import the rows with numerical missing values

# %%
ms= df[df.select_dtypes(include=['number']).isnull().any(axis=1)]
print(ms)
# Out:
#       Manufacturer              Model  Sales in thousands Vehicle type  \
# 2    Acura          CL                             14.114    Passenger
# 15   Cadillac       Seville                        15.943    Passenger
# 33   Chrysler       Town & Country                 53.480          Car
# 38   Dodge          Intrepid                       88.028    Passenger
# 109  Oldsmobile     Intrigue                       38.554    Passenger
#
#      Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 2                   NaN          3.2       225.0      106.9   70.6   192.0
# 15               44.475          4.6       275.0      112.2   75.0   201.0
# 33                  NaN          NaN         NaN        NaN    NaN     NaN
# 38               22.505          2.7       202.0      113.0   74.7   203.7
# 109              24.150          3.5       215.0      109.0   73.6   195.9
#
#      Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# 2          3.470           17.2             26.0      1-Apr-14
# 15           NaN           18.5             22.0     29-Apr-15
# 33           NaN            NaN              NaN     13-Jul-15
# 38         3.489           17.0              NaN      6-Feb-14
# 109        3.455           18.0              NaN      4-Jan-15

# %% [markdown]
# ##  11. Sort the data w.r.t price_find the details of the most and the least expensive cars

# %%
df1=df.dropna(subset=['Price in thousands'])
sorted_df = df1.sort_values(by='Price in thousands', ascending=True)
print(sorted_df)
print("Least expensive car:", sorted_df.iloc[0])
print("Most expensive car:", sorted_df.iloc[-1])
# Out:
#       Manufacturer              Model  Sales in thousands Vehicle type  \
# 26   Chevrolet      Metro                          21.855    Passenger
# 62   Hyundai        Accent                         41.184    Passenger
# 129  Saturn         SL                             80.620    Passenger
# 140  Toyota         Tacoma                         84.087          Car
# 63   Hyundai        Elantra                        66.692    Passenger
# ..             ...                ...                 ...          ...
# 39   Dodge          Viper                           0.916    Passenger
# 125  Porsche        Carrera Coupe                   1.280    Passenger
# 126  Porsche        Carrera Cabriolet               1.866    Passenger
# 95   Mercedes-Benz  SL-Class                        3.311    Passenger
# 99   Mercedes-Benz  CL500                           0.954    Passenger
#
#      Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 26                9.235          1.0        55.0       93.1   62.6   149.4
# 62                9.699          1.5        92.0       96.1   65.7   166.7
# 129              10.685          1.9       100.0      102.4   66.4   176.9
# 140              11.528          2.4       142.0      103.3   66.5   178.7
# 63               11.799          2.0       140.0      100.4   66.9   174.0
# ..                  ...          ...         ...        ...    ...     ...
# 39               69.725          8.0       450.0       96.2   75.7   176.7
# 125              71.020          3.4       300.0       92.6   69.5   174.5
# 126              74.970          3.4       300.0       92.6   69.5   174.5
# 95               82.600          5.0       302.0       99.0   71.3   177.1
# 99               85.500          5.0       302.0      113.6   73.1   196.6
#
#      Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# 26         1.895           10.3             45.0     13-Apr-14
# 62         2.240           11.9             31.0      9-Oct-14
# 129        2.332           12.1             33.0     16-Aug-14
# 140        2.580           15.1             23.0      8-Jan-15
# 63         2.626           14.5             27.0     15-Nov-15
# ..           ...            ...              ...           ...
# 39         3.375           19.0             16.0      8-Jul-15
# 125        3.032           17.0             21.0     21-Dec-14
# 126        3.075           17.0             23.0      7-Nov-15
# 95         4.125           21.1             20.0     17-Mar-15
# 99         4.115           23.2             20.0      4-Nov-15
#
# [155 rows x 14 columns]
# Least expensive car: Manufacturer              Chevrolet
# Model                 Metro
# Sales in thousands               21.855
# Vehicle type                  Passenger
# Price in thousands                9.235
# Engine size                         1.0
# Horsepower                         55.0
# Wheelbase                          93.1
# Width                              62.6
# Length                            149.4
# Curb weight                       1.895
# Fuel capacity                      10.3
# Fuel efficiency                    45.0
# Latest Launch                 13-Apr-14
# Name: 26, dtype: object
# Most expensive car: Manufacturer              Mercedes-Benz
# Model                 CL500
# Sales in thousands                0.954
# Vehicle type                  Passenger
# Price in thousands                 85.5
# Engine size                         5.0
# Horsepower                        302.0
# Wheelbase                         113.6
# Width                              73.1
# Length                            196.6
# Curb weight                       4.115
# Fuel capacity                      23.2
# Fuel efficiency                    20.0
# Latest Launch                  4-Nov-15
# Name: 99, dtype: object

# %% [markdown]
# ##  12. Write a function to find min and max values of any column

# %%
def find_min_max(df):
 min_value = df["Fuel capacity"].min()
 max_value = df["Fuel capacity"].max()
 print(f"Min value :{min_value}")
 print(f"Max value :{max_value}")
find_min_max(df)
# Out:
# Min value :10.3
# Max value :32.0

# %% [markdown]
# ## 13. Call the above function to find min max of horse power, length, fuel efficiency

# %%
# Get min and max horsepower values
hp_min = df["Horsepower"].min()
hp_max = df["Horsepower"].max()
# Get rows where horsepower is min/max
hp_min_row = df[df["Horsepower"] == hp_min]
hp_max_row = df[df["Horsepower"] == hp_max]
print("\nHorsepower - Min:", hp_min, "\n", hp_min_row)
print("\nHorsepower - Max:", hp_max, "\n", hp_max_row)

lmin=df["Length"].min()
lmax=df["Length"].max()
print("\nLength -Min:",lmin)
print("\nLength -Max:",lmax)

fmin=df["Fuel efficiency"].min()
fmax=df["Fuel efficiency"].max()
print("\nFuel efficiency -Min:",fmin)
print("\nFuel efficiency -Max:",fmax)
# Out:
# Horsepower - Min: 55.0
#       Manufacturer              Model  Sales in thousands Vehicle type  \
# 26  Chevrolet      Metro                          21.855    Passenger
#
#     Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 26               9.235          1.0        55.0       93.1   62.6   149.4
#
#     Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# 26        1.895           10.3             45.0     13-Apr-14
#
# Horsepower - Max: 450.0
#       Manufacturer              Model  Sales in thousands Vehicle type  \
# 39  Dodge          Viper                           0.916    Passenger
#
#     Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 39              69.725          8.0       450.0       96.2   75.7   176.7
#
#     Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# 39        3.375           19.0             16.0      8-Jul-15
#
# Length -Min: 149.4
#
# Length -Max: 224.5
#
# Fuel efficiency -Min: 15.0
#
# Fuel efficiency -Max: 45.0

# %% [markdown]
# ## 14. Plot histogram of continuous numerical variable : price,sales,hoursepower,fuelefficiency

# %%
import matplotlib.pyplot as plt
numerical_vars = ['Price in thousands', 'Sales in thousands', 'Horsepower', 'Fuel efficiency']
df[numerical_vars].hist(bins=20, figsize=(12, 8))
plt.show()

# %% [markdown]
# ## 15. Probability density distribution of continuous numerical variable-length

# %%
import pandas as pd
from scipy.stats import gaussian_kde
# Load dataset
df = pd.read_csv("Car_sales.csv")
df.columns = df.columns.str.strip()
if "Length" in df.columns:
 df["Length"] = pd.to_numeric(df["Length"], errors="coerce")
 data = df["Length"].dropna()
 kde = gaussian_kde(data)
 density_values = kde.evaluate(data)
 result = pd.DataFrame({'Length': data, 'Density': density_values})
 print(result.head())
else:
 print("Error: 'Length' column not found in the dataset.")
# Out:
#    Length   Density
# 0   172.4  0.016206
# 1   192.9  0.027570
# 2   192.0  0.028122
# 3   196.6  0.023728
# 4   178.0  0.023772

# %% [markdown]
# ## 16. Count by category –group by manufacture

# %%
import pandas as pd
df = pd.read_csv("Car_sales.csv")
manufacturer_counts = df.groupby('Manufacturer').size().reset_index(name='Count')
print(manufacturer_counts)
# Out:
#      Manufacturer  Count
# 0   Acura              4
# 1   Audi               3
# 2   BMW                3
# 3   Buick              4
# 4   Cadillac           5
# 5   Chevrolet          9
# 6   Chrysler           7
# 7   Dodge             11
# 8   Ford              11
# 9   Honda              5
# 10  Hyundai            3
# 11  Infiniti           1
# 12  Jaguar             1
# 13  Jeep               3
# 14  Lexus              6
# 15  Lincoln            3
# 16  Mercedes-Benz      9
# 17  Mercury            6
# 18  Mitsubishi         7
# 19  Nissan             7
# 20  Oldsmobile         6
# 21  Plymouth           4
# 22  Pontiac            6
# 23  Porsche            3
# 24  Saab               2
# 25  Saturn             5
# 26  Subaru             2
# 27  Toyota             9
# 28  Volkswagen         6
# 29  Volvo              6

# %% [markdown]
# ## 17. Select all numerical variables

# %%
n_df=df.select_dtypes(include=['number'])
print(n_df.head())
# Out:
#    Sales in thousands  4-year resale value  Price in thousands  Engine size  \
# 0              16.919               16.360               21.50          1.8
# 1              39.384               19.875               28.40          3.2
# 2              14.114               18.225                 NaN          3.2
# 3               8.588               29.725               42.00          3.5
# 4              20.397               22.255               23.99          1.8
#
#    Horsepower  Wheelbase  Width  Length  Curb weight  Fuel capacity  \
# 0       140.0      101.2   67.3   172.4        2.639           13.2
# 1       225.0      108.1   70.3   192.9        3.517           17.2
# 2       225.0      106.9   70.6   192.0        3.470           17.2
# 3       210.0      114.6   71.4   196.6        3.850           18.0
# 4       150.0      102.6   68.2   178.0        2.998           16.4
#
#    Fuel efficiency
# 0             28.0
# 1             25.0
# 2             26.0
# 3             22.0
# 4             27.0

# %% [markdown]
# ## 18. Print correlation coefficient value of price and sales

# %%
print("Correlation between Price and Sales:",
      df['Price in thousands'].corr(df['Sales in thousands']))
# Out:
# Correlation between Price and Sales: -0.3047344541294122

# %% [markdown]
# ## 19. Plot correlation of price and sales using scatterplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("Car_sales.csv")
df.columns = df.columns.str.lower()
price_col = next((col for col in df.columns if "price" in col), None)
sales_col = next((col for col in df.columns if "sales" in col or "units" in col), None)
if price_col and sales_col:
 plt.figure(figsize=(8, 5))
 sns.scatterplot(x=df[price_col], y=df[sales_col])
 plt.xlabel(price_col.capitalize())
 plt.ylabel(sales_col.capitalize())
 plt.title("Price vs Sales Scatter Plot")
 plt.show()
else:
 print("Error: Could not find 'price' and 'sales' columns.")

# %% [markdown]
# ## 20.Pair plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("Car_sales.csv")
df.columns = df.columns.str.lower()
sns.pairplot(df)
plt.show()

# %% [markdown]
# ## 21. Boxplot of sales of different manufacturer

# %%
sns.boxplot(x='Manufacturer', y='Sales in thousands', data=df)

# Rotate x-axis labels for better visibility
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %% [markdown]
# ## 22. Boxplot of other numerical variables w.r.t manufacture

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("Car_sales.csv")
df.columns = df.columns.str.strip()
numerical_columns = df.select_dtypes(include=['number']).columns
numerical_columns = [col for col in numerical_columns if col !=
'Manufacturer']
if 'Manufacturer' in df.columns:
# Create boxplots for each numerical column with respect to 'Manufacturer'
 for col in numerical_columns:
  plt.figure(figsize=(10, 6))
  sns.boxplot(x='Manufacturer', y=col, data=df)
  plt.title(f'Boxplot of {col} by Manufacturer')
  plt.xlabel('Manufacturer')
  plt.ylabel(col)
  plt.xticks(rotation=45)
  plt.show()
else:
 print("Error: 'Manufacturer' column not found in the dataset.")

# %% [markdown]
# ## 23. Divide the data into input and output y=sales in thousand, x=all other variables

# %%
X = df.drop(columns=['Sales in thousands'])
y = df['Sales in thousands']

# %% [markdown]
# ## 24. Encode other categorical variables using label encoder

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# List of categorical columns to encode
categorical_columns = ['Manufacturer', 'Model']

# Apply LabelEncoder
for col in categorical_columns:
    df[col] = label_encoder.fit_transform(df[col])

# Display first few rows
print("After Label Encoding:\n", df)
# Out:
# After Label Encoding:
#       Manufacturer  Model  Sales in thousands  4-year resale value  \
# 0               0     79              16.919               16.360
# 1               0    143              39.384               19.875
# 2               0     25              14.114               18.225
# 3               0    115               8.588               29.725
# 4               1      8              20.397               22.255
# ..            ...    ...                 ...                  ...
# 152            29    148               3.545                  NaN
# 153            29    125              15.245                  NaN
# 154            29    149              17.531                  NaN
# 155            29     24               3.493                  NaN
# 156            29    126              18.969                  NaN
#
#     Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# 1      Passenger               28.40          3.2       225.0      108.1
# 2      Passenger                 NaN          3.2       225.0      106.9
# 3      Passenger               42.00          3.5       210.0      114.6
# 4      Passenger               23.99          1.8       150.0      102.6
# ..           ...                 ...          ...         ...        ...
# 152    Passenger               24.40          1.9       160.0      100.5
# 153    Passenger               27.50          2.4       168.0      104.9
# 154    Passenger               28.80          2.4       168.0      104.9
# 155    Passenger               45.50          2.3       236.0      104.9
# 156    Passenger               36.00          2.9       201.0      109.9
#
#      Width  Length  Curb weight  Fuel capacity  Fuel efficiency Latest Launch
# 0     67.3   172.4        2.639           13.2             28.0      2-Feb-14
# 1     70.3   192.9        3.517           17.2             25.0      6-Mar-15
# 2     70.6   192.0        3.470           17.2             26.0      1-Apr-14
# 3     71.4   196.6        3.850           18.0             22.0      3-Oct-15
# 4     68.2   178.0        2.998           16.4             27.0     10-Aug-15
# ..     ...     ...          ...            ...              ...           ...
# 152   67.6   176.6        3.042           15.8             25.0     21-Sep-15
# 153   69.3   185.9        3.208           17.9             25.0     24-Nov-14
# 154   69.3   186.2        3.259           17.9             25.0     25-Jun-15
# 155   71.5   185.7        3.601           18.5             23.0     26-Apr-15
# 156   72.1   189.8        3.600           21.1             24.0     14-Nov-15
#
# [157 rows x 15 columns]

# %% [markdown]
# ## 25. Encode categorical variable vehicle type using one-hot encoder

# %%
# Apply One-Hot Encoding to 'Vehicle Type'
df = pd.get_dummies(df, columns=['Vehicle type'])

# Display first few rows
print("After One-Hot Encoding:\n", df)
# Out:
# After One-Hot Encoding:
#       Manufacturer  Model  Sales in thousands  4-year resale value  \
# 0               0     79              16.919               16.360
# 1               0    143              39.384               19.875
# 2               0     25              14.114               18.225
# 3               0    115               8.588               29.725
# 4               1      8              20.397               22.255
# ..            ...    ...                 ...                  ...
# 152            29    148               3.545                  NaN
# 153            29    125              15.245                  NaN
# 154            29    149              17.531                  NaN
# 155            29     24               3.493                  NaN
# 156            29    126              18.969                  NaN
#
#      Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# 2                   NaN          3.2       225.0      106.9   70.6   192.0
# 3                 42.00          3.5       210.0      114.6   71.4   196.6
# 4                 23.99          1.8       150.0      102.6   68.2   178.0
# ..                  ...          ...         ...        ...    ...     ...
# 152               24.40          1.9       160.0      100.5   67.6   176.6
# 153               27.50          2.4       168.0      104.9   69.3   185.9
# 154               28.80          2.4       168.0      104.9   69.3   186.2
# 155               45.50          2.3       236.0      104.9   71.5   185.7
# 156               36.00          2.9       201.0      109.9   72.1   189.8
#
#      Curb weight  Fuel capacity  Fuel efficiency Latest Launch  \
# 0          2.639           13.2             28.0      2-Feb-14
# 1          3.517           17.2             25.0      6-Mar-15
# 2          3.470           17.2             26.0      1-Apr-14
# 3          3.850           18.0             22.0      3-Oct-15
# 4          2.998           16.4             27.0     10-Aug-15
# ..           ...            ...              ...           ...
# 152        3.042           15.8             25.0     21-Sep-15
# 153        3.208           17.9             25.0     24-Nov-14
# 154        3.259           17.9             25.0     25-Jun-15
# 155        3.601           18.5             23.0     26-Apr-15
# 156        3.600           21.1             24.0     14-Nov-15
#
#      Vehicle type_Car  Vehicle type_Passenger
# 0               False                    True
# 1               False                    True
# 2               False                    True
# 3               False                    True
# 4               False                    True
# ..                ...                     ...
# 152             False                    True
# 153             False                    True
# 154             False                    True
# 155             False                    True
# 156             False                    True
#
# [157 rows x 16 columns]

# %% [markdown]
# ## 26.Split the data set into train and test set 70% train set 10% test set

# %%
from sklearn.model_selection import train_test_split

# Split data into Train (70%) and Test (30%)
train_data, test_data = train_test_split(df, test_size=0.3, random_state=42)

# Display dataset sizes
print(f"Training Set: {train_data.shape}")
print(f"Test Set: {test_data.shape}")
# Out:
# Training Set: (109, 16)
# Test Set: (48, 16)

# %% [markdown]
# ## 27. Apply feature scaling on numerical variables

# %%
from sklearn.preprocessing import StandardScaler

# Select numerical columns for scaling
numerical_columns = ['Sales in thousands', '4-year resale value', 'Price in thousands', 
                     'Engine size', 'Horsepower', 'Wheelbase', 'Width', 'Length', 
                     'Curb weight', 'Fuel capacity', 'Fuel efficiency']

# Initialize scaler
scaler = StandardScaler()

# Apply scaling on train and test data
train_data[numerical_columns] = scaler.fit_transform(train_data[numerical_columns])
test_data[numerical_columns] = scaler.transform(test_data[numerical_columns])

# Display first few rows after scaling
print("After Feature Scaling (Train Data):\n", train_data.head())
print("After Feature Scaling (Test Data):\n", test_data.head())
# Out:
# After Feature Scaling (Train Data):
#       Manufacturer  Model  Sales in thousands  4-year resale value  \
# 140            27    144            0.534810            -0.810100
# 11              3    121           -0.246486            -0.332302
# 79             18     95           -0.475581            -0.953497
# 68             13     39            0.473144            -0.328287
# 149            28     70           -0.835972            -0.330008
#
#      Price in thousands  Engine size  Horsepower  Wheelbase     Width  \
# 140           -1.141028    -0.627320   -0.769503  -0.659128 -1.396887
# 11            -0.059247     0.751325    1.058239   0.169629  0.457873
# 79            -0.947875    -1.218167   -1.310366  -1.371569 -1.396887
# 68            -0.348309     0.948274    0.125718  -0.935381 -0.529338
# 149           -0.671932    -1.021218   -1.273065  -1.298871 -0.858408
#
#        Length  Curb weight  Fuel capacity  Fuel efficiency Latest Launch  \
# 140 -0.759621    -1.318314      -0.751778        -0.225534      8-Jan-15
# 11   0.709260     0.291298      -0.093909        -0.225534      9-Mar-15
# 79  -1.187695    -1.869895      -1.272592         1.536003     23-Apr-14
# 68  -1.699705    -0.292040       0.591372        -0.980478     10-May-14
# 149 -2.052237    -1.014109      -0.888834         0.529411      4-Jan-15
#
#      Vehicle type_Car  Vehicle type_Passenger
# 140              True                   False
# 11              False                    True
# 79              False                    True
# 68               True                   False
# 149             False                    True
# After Feature Scaling (Test Data):
#       Manufacturer  Model  Sales in thousands  4-year resale value  \
# 126            23     33           -0.901113             5.840637
# 45              7     32            2.240397            -0.529043
# 133            25     84           -0.060684                  NaN
# 138            27     16            0.181369             0.172454
# 111            20     15           -0.677153             0.373209
#
#      Price in thousands  Engine size  Horsepower  Wheelbase     Width  \
# 126            3.842294     0.357426    2.177266  -2.214866 -0.499423
# 45            -0.509727    -0.627320   -0.620300   0.794831  1.684408
# 133           -0.867519    -0.824269   -0.862755  -0.193861 -0.649000
# 138           -0.040003    -0.036472    0.498726  -0.106624  0.158718
# 111            0.799217     0.948274    1.244744   0.867529  0.966437
#
#        Length  Curb weight  Fuel capacity  Fuel efficiency Latest Launch  \
# 126 -1.112153    -0.490944      -0.230965        -0.225534      7-Nov-15
# 45  -0.121707     0.274583       0.591372         0.026114      9-Jan-15
# 133  0.222431    -0.766734      -1.300003         1.032707     12-Apr-14
# 138  0.348335     0.080694       0.180203         0.529411     31-Aug-15
# 111  1.481471     0.999995       0.180203        -0.477182     18-Feb-15
#
#      Vehicle type_Car  Vehicle type_Passenger
# 126             False                    True
# 45               True                   False
# 133             False                    True
# 138             False                    True
# 111             False                    True
